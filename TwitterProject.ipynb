# %% [markdown]
# <a href="https://colab.research.google.com/github/PaulAMoretto/TwitterProjectICS412/blob/main/TwitterProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
import csv
import datetime
import pandas as pd
#Import all libraries needed for analysis
#List of tweet Ids for tweet analysis
JenList = [1560704006892265472,1559274903798439936,1583115219035127811,1583867638773878791,1584350979159658497,1589789849384411137] 
WalzList =[1584597890617724928 ,1585694736786096128,1589970730493808641,1590431641587286016]

# %%
#Provide API keys and validation tokens for Twitter API (Paid Only post 4/1/2023)
consumer_key ="*************************"
consumer_secret ="*************************"
access_token ="*************************"
access_secret ="*************************"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token,access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

#Validate login successful
if api.verify_credentials() == False:
    print("The user credentials are invalid.")
else:
    print("The user credentials are valid.")
# Out:
# The user credentials are valid.

# %%
import botometer
#import and log into botometer API for individual retweet analysis.
rapidapi_key = "*************************"
twitter_app_auth = {
    'consumer_key': "*************************",
    'consumer_secret': "*************************",
    'access_token': "*************************",
    'access_token_secret': "*************************",
  }
  #API call limit to 500 per day. 
bom = botometer.Botometer(wait_on_ratelimit=True,
                          rapidapi_key=rapidapi_key,
                          **twitter_app_auth)

# %%
#Test-case validation to retreive data from Twitter API through tweepy. 

#Parameters of tweet extraction. 
user = "Tim_Walz"
start_date = pd.to_datetime("2022-10-27").date() 
end_date= pd.to_datetime("2022-10-27").date() 

tweets = api.user_timeline(screen_name = user, count = 200, include_rts=True, tweet_mode ='extended')

tweetid= api.get_status(1585617963876507650)


if api.verify_credentials() == False:
    print("The user credentials are invalid.")
else:
    print("The user credentials are valid.")
# Out:
# The user credentials are valid.

# %%
#Test-case to extract liked tweets. 
likeTweet=[]

for friend in api.friends(screen_name=user):
    likeTweet.append(friend)
print(likeTweet)
df = pd.DataFrame(likeTweet)
df.to_csv("likes1.csv")

# %%
#Prepair implementation of data extraction from API.
retweeters=[]
for tweet in tweets:
    if tweet.created_at.date() >= start_date and tweet.created_at.date() <= end_date:    
       #target status id = 1585617963876507650
        print(tweet.full_text)    
        print(tweet.full_text)
        retweets= api.retweets(tweet.id, count=100) #Twitter API limited to 100 calls. Not sorted. 
        for retweet in retweets:
            retweeters.append(retweet.user.screen_name)
df = pd.DataFrame(retweeters)
if api.verify_credentials() == False:
    print("The user credentials are invalid.")
else:
    print("The user credentials are valid.")
# Out:
# Minnesota cannot be divided by dangerous, anti-democratic extremists.
# Minnesota cannot be divided by dangerous, anti-democratic extremists.
# The choice between your health and pocketbook should never be on the table. That's why I’ll always fight for Minnesotans to have access to affordable health care.
# The choice between your health and pocketbook should never be on the table. That's why I’ll always fight for Minnesotans to have access to affordable health care.
# I'm honored to be endorsed by more than 30 Minnesota mayors. Because coming together to hear about what's happening at the local level is critical in continuing to move our state forward as One Minnesota.
# https://t.co/ggPINuyZx0
# I'm honored to be endorsed by more than 30 Minnesota mayors. Because coming together to hear about what's happening at the local level is critical in continuing to move our state forward as One Minnesota.
# https://t.co/ggPINuyZx0
# Minnesota cannot become a test lab for extreme agendas – @PeggyFlanagan and I will not let that happen.
#
# Help us fight back against extremism, uphold our Minnesota values, and move our state forward: https://t.co/54V9Zoh499
# Minnesota cannot become a test lab for extreme agendas – @PeggyFlanagan and I will not let that happen.
#
# Help us fight back against extremism, uphold our Minnesota values, and move our state forward: https://t.co/54V9Zoh499
# What an honor! Thrilled to be endorsed by @GovJVentura.
#
# I'm committed to being a governor for all Minnesotans, and I’ll work with anyone who’s willing to work with me to get things done.
#
# Thank you, Jesse, for taking the unprecedented step to cast your independent vote for me! https://t.co/QABgPjFNX9
# What an honor! Thrilled to be endorsed by @GovJVentura.
#
# I'm committed to being a governor for all Minnesotans, and I’ll work with anyone who’s willing to work with me to get things done.
#
# Thank you, Jesse, for taking the unprecedented step to cast your independent vote for me! https://t.co/QABgPjFNX9
# The user credentials are valid.

# %%
#Test export to cvs file for next phase of analysis. 

df.to_csv("Project1v2.csv") #Write to file successful

# %%
#Create list to store retweeters for Bot score submission.
RetweetList=[]
for i in WalzList: #List of tweet Ids for anaylsis.
    retweeter = api.retweets(i, count = 100)# API call to request retweets from tweet id list. Limit to 100 to avoid cool-down. 
    RetweetList.append(i)
    for j in retweeter:
        RetweetList.append(j.user.screen_name)
    print(RetweetList) # confirm list is populated before transition to dataframe.

dfRetweet = pd.DataFrame(RetweetList)  #List placed into dataframe for cvs export.
dfRetweet.to_csv("Retweeters2.csv")
# Out:
# [1584597890617724928, 'bdunn300', 'samanth96173787', 'julie55443', 'GopherTheW', 'nmjohnson89', 'mnhumanrights', 'DrWalzMN', 'JodyAlford17', 'DianeRochMN', 'claybyington', 'magentanetzwerk', 'cj_devaan', 'wildmarshphoto', 'cbs144', 'pamgriffa', 'GSwensonSD', 'carsonca', 'OHarrysChar', 'Janeway12004', 'Skel531', 'ConradHarms', 'robgriddle', '2672Local', 'dolly_horse', 'cdmorben', 'KarenJMerchant1', 'mrdunaganbailey', 'ConnieS53426503', 'EkbMary', 'Koogslaw', 'RiceCountyDFL', 'jenwo513', 'ouboomer61', 'AmyOnThePrairie', 'dandrenorton', 'mariedangelo22', 'BonneHargan', 'pat_thiel', 'Cindi1218', 'msbwul', 'IndivisibleMN58', 'SparkAlicia', 'Dirtface1', 'TShark4', 'frenfer123', 'LiLSilverJ', 'PHILCP69', 'BizonHornsUp', 'AnneLueben', 'purpleardvark', 'Chazraps', 'nsjww', 'MagentaMN', 'RTeachquijote', 'BillGoodermont', 'MorrisOldtom', 'jonimanderson', 'SharonJ94772600', 'MssBrown2u', 'pblefty3', 'OpalEssence1990', 'JenniferNicoleN', 'krisartis123', 'SibilYarn', 'Lmhaydu', 'james_lagow', 'Candor2016', 'Elizabe70853104', 'sue18137535', 'barlondsmith', 'jaylindgren08', 'ItsThiaRose', 'Mjaysmama', 'Phoenixcruiser1', 'mst3kharris', 'crazylunchguy', 'KarenWe44853431', 'Anytweetya', 'garvis_bill', 'tracy_marie25', 'ArealbossAM', 'AzSalmen', 'theusedtommo', 'missb62', 'MerryJon52', 'vpmattsaxe', 'gar757', 'DZPoodle']
# [1584597890617724928, 'bdunn300', 'samanth96173787', 'julie55443', 'GopherTheW', 'nmjohnson89', 'mnhumanrights', 'DrWalzMN', 'JodyAlford17', 'DianeRochMN', 'claybyington', 'magentanetzwerk', 'cj_devaan', 'wildmarshphoto', 'cbs144', 'pamgriffa', 'GSwensonSD', 'carsonca', 'OHarrysChar', 'Janeway12004', 'Skel531', 'ConradHarms', 'robgriddle', '2672Local', 'dolly_horse', 'cdmorben', 'KarenJMerchant1', 'mrdunaganbailey', 'ConnieS53426503', 'EkbMary', 'Koogslaw', 'RiceCountyDFL', 'jenwo513', 'ouboomer61', 'AmyOnThePrairie', 'dandrenorton', 'mariedangelo22', 'BonneHargan', 'pat_thiel', 'Cindi1218', 'msbwul', 'IndivisibleMN58', 'SparkAlicia', 'Dirtface1', 'TShark4', 'frenfer123', 'LiLSilverJ', 'PHILCP69', 'BizonHornsUp', 'AnneLueben', 'purpleardvark', 'Chazraps', 'nsjww', 'MagentaMN', 'RTeachquijote', 'BillGoodermont', 'MorrisOldtom', 'jonimanderson', 'SharonJ94772600', 'MssBrown2u', 'pblefty3', 'OpalEssence1990', 'JenniferNicoleN', 'krisartis123', 'SibilYarn', 'Lmhaydu', 'james_lagow', 'Candor2016', 'Elizabe70853104', 'sue18137535', 'barlondsmith', 'jaylindgren08', 'ItsThiaRose', 'Mjaysmama', 'Phoenixcruiser1', 'mst3kharris', 'crazylunchguy', 'KarenWe44853431', 'Anytweetya', 'garvis_bill', 'tracy_marie25', 'ArealbossAM', 'AzSalmen', 'theusedtommo', 'missb62', 'MerryJon52', 'vpmattsaxe', 'gar757', 'DZPoodle', 1585694736786096128, 'votematters2021', 'MZDIVA4LYFE0915', 'BergumT', 'faympras', 'EricroyN', 'LauraTripp57', 'SarahStruck4', 'JeffJun80346519', 'Frye1Virginia', 'amyj9702', 'KatP147369', 'kathleen1350', 'cj_devaan', 'msdebmn', 'SenateDFL', 'tina_pede', 'ConradHarms', 'marymackcomedy', 'kaybeekh', 'PeleKoolAid', 'mc1748', 'sweetbabygames6', 'robgriddle', 'SasekThomas', 'fields_hl', 'MLeibfried', 'DaleTL', 'mgido', 'kmneun', 'toms999', 'ElizabethLund11', 'dmillercfp', 'queenoftens', 'MattMoberg', 'carol49er', 'LiLSilverJ', 'Vanvikes', 'freebluebird19', 'uswanie49', 'RiceCountyDFL', 'federicolentini', 'grammycam', 'Empowerer', 'MN_Carlson', 'noventurenogain', 'Bemidji_Rita', 'kperrymn', 'larsonand83', 'HennRegionsPD', 'jsc1835', 'robbynb', 'bowsensboating', 'mdb1958', 'marsbarrow', 'PHILCP69', 'Progressive538', 'LindaSFroiland', 'Kmmn41457539', 'BethDav50135482', 'bomber9996', 'lmuhm22', 'Molly1Jo', 'IndivisibleMN58', 'BarbWanner', 'MaryjoNairn', 'TerryHardin22', 'JoMaloneMN', 'G99414846', 'albert_cashier', 'justpeachy543', 'LisaSwedenburg1', 'KcBuck', 'ChrisCondo3', 'NorthernLaces', 'flyhyland', 'bbpfankuch', 'edinaindivis', 'zentiques75', 'msmae1441', 'shamanbart', 'mary_gabel', 'KrisOrluck', 'MaryM500', 'jeromehoffman', 'JulieSirrs', 'forsberg_scott', 'adodger78', 'BurnettCynthia', 'TaggartNancy', '15a7cdc77164414', 'JoanEmp6', 'cta1327', 'Restinpeacefred']
# [1584597890617724928, 'bdunn300', 'samanth96173787', 'julie55443', 'GopherTheW', 'nmjohnson89', 'mnhumanrights', 'DrWalzMN', 'JodyAlford17', 'DianeRochMN', 'claybyington', 'magentanetzwerk', 'cj_devaan', 'wildmarshphoto', 'cbs144', 'pamgriffa', 'GSwensonSD', 'carsonca', 'OHarrysChar', 'Janeway12004', 'Skel531', 'ConradHarms', 'robgriddle', '2672Local', 'dolly_horse', 'cdmorben', 'KarenJMerchant1', 'mrdunaganbailey', 'ConnieS53426503', 'EkbMary', 'Koogslaw', 'RiceCountyDFL', 'jenwo513', 'ouboomer61', 'AmyOnThePrairie', 'dandrenorton', 'mariedangelo22', 'BonneHargan', 'pat_thiel', 'Cindi1218', 'msbwul', 'IndivisibleMN58', 'SparkAlicia', 'Dirtface1', 'TShark4', 'frenfer123', 'LiLSilverJ', 'PHILCP69', 'BizonHornsUp', 'AnneLueben', 'purpleardvark', 'Chazraps', 'nsjww', 'MagentaMN', 'RTeachquijote', 'BillGoodermont', 'MorrisOldtom', 'jonimanderson', 'SharonJ94772600', 'MssBrown2u', 'pblefty3', 'OpalEssence1990', 'JenniferNicoleN', 'krisartis123', 'SibilYarn', 'Lmhaydu', 'james_lagow', 'Candor2016', 'Elizabe70853104', 'sue18137535', 'barlondsmith', 'jaylindgren08', 'ItsThiaRose', 'Mjaysmama', 'Phoenixcruiser1', 'mst3kharris', 'crazylunchguy', 'KarenWe44853431', 'Anytweetya', 'garvis_bill', 'tracy_marie25', 'ArealbossAM', 'AzSalmen', 'theusedtommo', 'missb62', 'MerryJon52', 'vpmattsaxe', 'gar757', 'DZPoodle', 1585694736786096128, 'votematters2021', 'MZDIVA4LYFE0915', 'BergumT', 'faympras', 'EricroyN', 'LauraTripp57', 'SarahStruck4', 'JeffJun80346519', 'Frye1Virginia', 'amyj9702', 'KatP147369', 'kathleen1350', 'cj_devaan', 'msdebmn', 'SenateDFL', 'tina_pede', 'ConradHarms', 'marymackcomedy', 'kaybeekh', 'PeleKoolAid', 'mc1748', 'sweetbabygames6', 'robgriddle', 'SasekThomas', 'fields_hl', 'MLeibfried', 'DaleTL', 'mgido', 'kmneun', 'toms999', 'ElizabethLund11', 'dmillercfp', 'queenoftens', 'MattMoberg', 'carol49er', 'LiLSilverJ', 'Vanvikes', 'freebluebird19', 'uswanie49', 'RiceCountyDFL', 'federicolentini', 'grammycam', 'Empowerer', 'MN_Carlson', 'noventurenogain', 'Bemidji_Rita', 'kperrymn', 'larsonand83', 'HennRegionsPD', 'jsc1835', 'robbynb', 'bowsensboating', 'mdb1958', 'marsbarrow', 'PHILCP69', 'Progressive538', 'LindaSFroiland', 'Kmmn41457539', 'BethDav50135482', 'bomber9996', 'lmuhm22', 'Molly1Jo', 'IndivisibleMN58', 'BarbWanner', 'MaryjoNairn', 'TerryHardin22', 'JoMaloneMN', 'G99414846', 'albert_cashier', 'justpeachy543', 'LisaSwedenburg1', 'KcBuck', 'ChrisCondo3', 'NorthernLaces', 'flyhyland', 'bbpfankuch', 'edinaindivis', 'zentiques75', 'msmae1441', 'shamanbart', 'mary_gabel', 'KrisOrluck', 'MaryM500', 'jeromehoffman', 'JulieSirrs', 'forsberg_scott', 'adodger78', 'BurnettCynthia', 'TaggartNancy', '15a7cdc77164414', 'JoanEmp6', 'cta1327', 'Restinpeacefred', 1589970730493808641, 'JoeyNel20259583', 'kabiu', 'DFLCD2', 'SawyerWilliemae', 'ArtusBunnyBane', 'StephanieStoes1', 'HanamannSuz', 'WildGrrl14', 'SenatorCarlson', 'AamoldNelson', 'dodlil04', 'textifyer59', 'juliad444', 'Mojo70351087', 'RacistTwiitter', 'monicasloves', 'gar757', 'DragonFlyMSP', 'UsuallyBut', 'jess1962', 'dianefrost', 'KAkabueze', 'laminn', 'NajeebaSyeed', 'Kmmn41457539', 'EmersonFan1', 'ChicagoItaliano', 'Andallthatjazz2', 'madtilGOPisgone', 'shatteredshards', 'citizenstewart', 'IssacVirginia', 'suepafan', 'KtHathSpoken', 'CatharineTrebn1', 'FithanegestWel1', 'amanda_hocking', 'tammaradlawhead', 'TalkinToU', 'potvin_jennifer', 'Iuc_4s', 'MerryJon52', 'sdmohamed24', 'raptors606', 'Sean17856226', 'SThebulbmin', 'jensenlmr5', 'mdb1958', 'xaidan13', 'taetaegoalie', 'jenebene', 'MyMediaPractice', 'eriklundborg93', 'ACommonGood1', 'PurpleNation84', 'itsallbs2017', 'erishomsncom1', 'IndivisibleSPGM', 'LaurenJane2588', 'KJTeder', '2antsy', 'JKaneK99', 'rshwaidy', 'donnahammond47', 'bethhentges', 'MaineOwl', 'EthanDinauer', 'KayLauffer1', 'LoveAmelia5', 'BrandonRubow', 'JoshBak73707600', 'MrTupperwar3', 'KCSnowGlobe', 'SENSIMILLIEA', 'TreeAffinity', 'JordanKrsnak', 'bridget4luv', 'bettynotto', 'LiLSilverJ', 'VoteHealth', 'TeresConnor', 'BenjaBeee', 'JVivone', 'nancywgon ...
# [1584597890617724928, 'bdunn300', 'samanth96173787', 'julie55443', 'GopherTheW', 'nmjohnson89', 'mnhumanrights', 'DrWalzMN', 'JodyAlford17', 'DianeRochMN', 'claybyington', 'magentanetzwerk', 'cj_devaan', 'wildmarshphoto', 'cbs144', 'pamgriffa', 'GSwensonSD', 'carsonca', 'OHarrysChar', 'Janeway12004', 'Skel531', 'ConradHarms', 'robgriddle', '2672Local', 'dolly_horse', 'cdmorben', 'KarenJMerchant1', 'mrdunaganbailey', 'ConnieS53426503', 'EkbMary', 'Koogslaw', 'RiceCountyDFL', 'jenwo513', 'ouboomer61', 'AmyOnThePrairie', 'dandrenorton', 'mariedangelo22', 'BonneHargan', 'pat_thiel', 'Cindi1218', 'msbwul', 'IndivisibleMN58', 'SparkAlicia', 'Dirtface1', 'TShark4', 'frenfer123', 'LiLSilverJ', 'PHILCP69', 'BizonHornsUp', 'AnneLueben', 'purpleardvark', 'Chazraps', 'nsjww', 'MagentaMN', 'RTeachquijote', 'BillGoodermont', 'MorrisOldtom', 'jonimanderson', 'SharonJ94772600', 'MssBrown2u', 'pblefty3', 'OpalEssence1990', 'JenniferNicoleN', 'krisartis123', 'SibilYarn', 'Lmhaydu', 'james_lagow', 'Candor2016', 'Elizabe70853104', 'sue18137535', 'barlondsmith', 'jaylindgren08', 'ItsThiaRose', 'Mjaysmama', 'Phoenixcruiser1', 'mst3kharris', 'crazylunchguy', 'KarenWe44853431', 'Anytweetya', 'garvis_bill', 'tracy_marie25', 'ArealbossAM', 'AzSalmen', 'theusedtommo', 'missb62', 'MerryJon52', 'vpmattsaxe', 'gar757', 'DZPoodle', 1585694736786096128, 'votematters2021', 'MZDIVA4LYFE0915', 'BergumT', 'faympras', 'EricroyN', 'LauraTripp57', 'SarahStruck4', 'JeffJun80346519', 'Frye1Virginia', 'amyj9702', 'KatP147369', 'kathleen1350', 'cj_devaan', 'msdebmn', 'SenateDFL', 'tina_pede', 'ConradHarms', 'marymackcomedy', 'kaybeekh', 'PeleKoolAid', 'mc1748', 'sweetbabygames6', 'robgriddle', 'SasekThomas', 'fields_hl', 'MLeibfried', 'DaleTL', 'mgido', 'kmneun', 'toms999', 'ElizabethLund11', 'dmillercfp', 'queenoftens', 'MattMoberg', 'carol49er', 'LiLSilverJ', 'Vanvikes', 'freebluebird19', 'uswanie49', 'RiceCountyDFL', 'federicolentini', 'grammycam', 'Empowerer', 'MN_Carlson', 'noventurenogain', 'Bemidji_Rita', 'kperrymn', 'larsonand83', 'HennRegionsPD', 'jsc1835', 'robbynb', 'bowsensboating', 'mdb1958', 'marsbarrow', 'PHILCP69', 'Progressive538', 'LindaSFroiland', 'Kmmn41457539', 'BethDav50135482', 'bomber9996', 'lmuhm22', 'Molly1Jo', 'IndivisibleMN58', 'BarbWanner', 'MaryjoNairn', 'TerryHardin22', 'JoMaloneMN', 'G99414846', 'albert_cashier', 'justpeachy543', 'LisaSwedenburg1', 'KcBuck', 'ChrisCondo3', 'NorthernLaces', 'flyhyland', 'bbpfankuch', 'edinaindivis', 'zentiques75', 'msmae1441', 'shamanbart', 'mary_gabel', 'KrisOrluck', 'MaryM500', 'jeromehoffman', 'JulieSirrs', 'forsberg_scott', 'adodger78', 'BurnettCynthia', 'TaggartNancy', '15a7cdc77164414', 'JoanEmp6', 'cta1327', 'Restinpeacefred', 1589970730493808641, 'JoeyNel20259583', 'kabiu', 'DFLCD2', 'SawyerWilliemae', 'ArtusBunnyBane', 'StephanieStoes1', 'HanamannSuz', 'WildGrrl14', 'SenatorCarlson', 'AamoldNelson', 'dodlil04', 'textifyer59', 'juliad444', 'Mojo70351087', 'RacistTwiitter', 'monicasloves', 'gar757', 'DragonFlyMSP', 'UsuallyBut', 'jess1962', 'dianefrost', 'KAkabueze', 'laminn', 'NajeebaSyeed', 'Kmmn41457539', 'EmersonFan1', 'ChicagoItaliano', 'Andallthatjazz2', 'madtilGOPisgone', 'shatteredshards', 'citizenstewart', 'IssacVirginia', 'suepafan', 'KtHathSpoken', 'CatharineTrebn1', 'FithanegestWel1', 'amanda_hocking', 'tammaradlawhead', 'TalkinToU', 'potvin_jennifer', 'Iuc_4s', 'MerryJon52', 'sdmohamed24', 'raptors606', 'Sean17856226', 'SThebulbmin', 'jensenlmr5', 'mdb1958', 'xaidan13', 'taetaegoalie', 'jenebene', 'MyMediaPractice', 'eriklundborg93', 'ACommonGood1', 'PurpleNation84', 'itsallbs2017', 'erishomsncom1', 'IndivisibleSPGM', 'LaurenJane2588', 'KJTeder', '2antsy', 'JKaneK99', 'rshwaidy', 'donnahammond47', 'bethhentges', 'MaineOwl', 'EthanDinauer', 'KayLauffer1', 'LoveAmelia5', 'BrandonRubow', 'JoshBak73707600', 'MrTupperwar3', 'KCSnowGlobe', 'SENSIMILLIEA', 'TreeAffinity', 'JordanKrsnak', 'bridget4luv', 'bettynotto', 'LiLSilverJ', 'VoteHealth', 'TeresConnor', 'BenjaBeee', 'JVivone', 'nancywgon ...

# %%
results = pd.DataFrame(columns = ["Name","Score"]) #create a name and bot score frame. 
print(results)
# Out:
# Empty DataFrame
# Columns: [Name, Score]
# Index: []

# %%
#DO NOT RUN UNLESS SURE ABOUT 500 MAX LIMIT USAGE!
listName= []
listScore=[]
for screen_name, results in bom.check_accounts_in(RetweetList): #Run list of user names and check for bot score
    listName.append(screen_name) #append list to username
    listScore.append(results)#append list to bot score
    print(screen_name)#check user names and check for timeout.
# Out:
# 1584597890617724928
# bdunn300
# samanth96173787
# julie55443
# GopherTheW
# nmjohnson89
# mnhumanrights
# DrWalzMN
# JodyAlford17
# DianeRochMN
# claybyington
# magentanetzwerk
# cj_devaan
# wildmarshphoto
# cbs144
# pamgriffa
# GSwensonSD
# carsonca
# OHarrysChar
# Janeway12004
# Skel531
# ConradHarms
# robgriddle
# 2672Local
# dolly_horse
# cdmorben
# KarenJMerchant1
# mrdunaganbailey
# ConnieS53426503
# EkbMary
# Koogslaw
# RiceCountyDFL
# jenwo513
# ouboomer61
# AmyOnThePrairie
# dandrenorton
# mariedangelo22
# BonneHargan
# pat_thiel
# Cindi1218
# msbwul
# IndivisibleMN58
# SparkAlicia
# Dirtface1
# TShark4
# frenfer123
# LiLSilverJ
# PHILCP69
# BizonHornsUp
# AnneLueben
# purpleardvark
# Chazraps
# nsjww
# MagentaMN
# RTeachquijote
# BillGoodermont
# MorrisOldtom
# jonimanderson
# SharonJ94772600
# MssBrown2u
# pblefty3
# OpalEssence1990
# JenniferNicoleN
# krisartis123
# SibilYarn
# Lmhaydu
# james_lagow
# Candor2016
# Elizabe70853104
# sue18137535
# barlondsmith
# jaylindgren08
# ItsThiaRose
# Mjaysmama
# Phoenixcruiser1
# mst3kharris
# crazylunchguy
# KarenWe44853431
# Anytweetya
# garvis_bill
# tracy_marie25
# ArealbossAM
# AzSalmen
# theusedtommo
# missb62
# MerryJon52
# vpmattsaxe
# gar757
# DZPoodle
# 1585694736786096128
# votematters2021
# MZDIVA4LYFE0915
# BergumT
# faympras
# EricroyN
# LauraTripp57
# SarahStruck4
# JeffJun80346519
# Frye1Virginia
# amyj9702
# KatP147369
# kathleen1350
# cj_devaan
# msdebmn
# SenateDFL
# tina_pede
# ConradHarms
# marymackcomedy
# kaybeekh
# PeleKoolAid
# mc1748
# sweetbabygames6
# robgriddle
# SasekThomas
# fields_hl
# MLeibfried
# DaleTL
# mgido
# kmneun
# toms999
# ElizabethLund11
# dmillercfp
# queenoftens
# MattMoberg
# carol49er
# LiLSilverJ
# Vanvikes
# freebluebird19
# uswanie49
# RiceCountyDFL
# federicolentini
# grammycam
# Empowerer
# MN_Carlson
# noventurenogain
# Bemidji_Rita
# kperrymn
# larsonand83
# HennRegionsPD
# jsc1835
# robbynb
# bowsensboating
# mdb1958
# marsbarrow
# PHILCP69
# Progressive538
# LindaSFroiland
# Kmmn41457539
# BethDav50135482
# bomber9996
# lmuhm22
# Molly1Jo
# IndivisibleMN58
# BarbWanner
# MaryjoNairn
# TerryHardin22
# JoMaloneMN
# G99414846
# albert_cashier
# justpeachy543
# LisaSwedenburg1
# KcBuck
# ChrisCondo3
# NorthernLaces
# flyhyland
# bbpfankuch
# edinaindivis
# zentiques75
# msmae1441
# shamanbart
# mary_gabel
# KrisOrluck
# MaryM500
# jeromehoffman
# JulieSirrs
# forsberg_scott
# adodger78
# BurnettCynthia
# TaggartNancy
# 15a7cdc77164414
# JoanEmp6
# cta1327
# Restinpeacefred
# 1589970730493808641
# JoeyNel20259583
# kabiu
# DFLCD2
# SawyerWilliemae
# ArtusBunnyBane
# StephanieStoes1
# HanamannSuz
# WildGrrl14
# SenatorCarlson
# AamoldNelson
# dodlil04
# textifyer59
# juliad444
# Mojo70351087
# RacistTwiitter
# monicasloves
# gar757
# DragonFlyMSP
# UsuallyBut
# jess1962
# dianefrost
# KAkabueze
# laminn
# NajeebaSyeed
# Kmmn41457539
# EmersonFan1
# ChicagoItaliano
# Andallthatjazz2
# madtilGOPisgone
# shatteredshards
# citizenstewart
# IssacVirginia
# suepafan
# KtHathSpoken
# CatharineTrebn1
# FithanegestWel1
# amanda_hocking
# tammaradlawhead
# TalkinToU
# potvin_jennifer
# Iuc_4s
# MerryJon52
# sdmohamed24
# raptors606
# Sean17856226
# SThebulbmin
# jensenlmr5
# mdb1958
# xaidan13
# taetaegoalie
# jenebene
# MyMediaPractice
# eriklundborg93
# ACommonGood1
# PurpleNation84
# itsallbs2017
# erishomsncom1
# IndivisibleSPGM
# LaurenJane2588
# KJTeder
# 2antsy
# JKaneK99
# rshwaidy
# donnahammond47
# bethhentges
# MaineOwl
# EthanDinauer
# KayLauffer1
# LoveAmelia5
# BrandonRubow
# JoshBak73707600
# MrTupperwar3
# KCSnowGlobe
# SENSIMILLIEA
# TreeAffinity
# JordanKrsnak
# bridget4luv
# bettynotto
# LiLSilverJ
# VoteHealth
# TeresConnor
# BenjaBeee
# JVivone
# nancywgonzalez
# dflsd34
# LindaSFroiland
# drewpowell97
# KrisOrluck
# 1590431641587286016
# Bob_Stinson1234
# stevecstny
# cardgames15
# KelvinH87468048
# stoffel_mark
# janet_yackle
# timothyghorton
# getjigwidnav
# DaveGulstrand
# Bob_Stinson1234
# pejo0501
# cj_devaan
# Garrett41863071
# MWPolitics101
# Midw3stMom
# SweetSueBlue
# MplsMe
# kylmxnglin
# babiemk
# notsoyounggrunt
# Mycromatic_1
# Murp1953Tim
# SportsVikingBro
# RupekRupek15
# kareahum
# VoteHealth
# VanditaMoon
# TanyaCo81507505
# Oldlady12345
# GSwensonSD
# dawnmariemn1
# onebluesky4
# carolfriess
# LeLe5417
# jrmak0049
# JohnHaun19
# TShark4
# RobertW04523526
# hilary23lynn
# avon_mn
# comicmizchief
# luciana0208
# PrincessBelaire
# Falcon7317
# AvalonSwenson
# DFLsd47
# ElizabethKipp8
# SammyJKoza
# thegideonboots
# MNPandora
# ImamAsadZaman
# Tania6T
# XenaMn
# Chonky_Chonkers
# bgcath007
# 4rest4thetrees
# JesusNarrowWay
# nmofsrr
# lolatoni
# ET_okiguess
# BrodieMart55
# MerryJon52
# KeanuReeve5252
# MaikiaYang2015
# awsomeninja119
# ejrun22
# votingspade
# probablytoasted
# annabellah2000
# TalkinToU
# sa41972697
# MNDFL57
# SilentEkoTV
# BDBgoldens3
# MumBot2000
# swirlingthinks
# willywi37028671
# matthewfoley48
# pjniska
# gar757
# evamaile
# Vicki00431234
# RobWolter1
# lil_BabyChickie
# ForsetiHenrik
# MrsYoung0816
# NajeebaSyeed
# TeresConnor

# %%
final = pd.DataFrame() #create final dataframe for export to csv.
#manipulate data to property formate data, list of list of lists.
final.insert(0,"Name","")
final.insert(1,"Score","")
final.insert(2,"Raw","")
dfls = pd.DataFrame(listScore)
#print(final)
index = 0
indexScore = 1
final["Score"] = dfls["cap"]
final["Name"] = listName
final = final.drop(labels=0, axis=0)
rawlist=[]

# %%
print(dfbot["display_scores"]["english"]['overall'])#check list formatting for export

# %%
final.to_csv("ScoresBotstestwalz2.csv") #Final Export.
